# %% [markdown]
# ### Creating Database Files

# %% [markdown]
# This code creates a text file containing a json of all the institutions in the assist.org database.

# %%
import pandas as pd
import requests
import json

api_url = "https://assist.org/api/institutions"
response = requests.get(api_url).json()

dfAll = pd.DataFrame(columns=['id', 'name', 'code', 'isCCC'])

for i in response:
    entry = {'id': i['id'], 'name': i['names'][0]['name'], 'code': i['code'], 'isCCC': i['isCommunityCollege']}
    dfAll = pd.concat([dfAll, pd.DataFrame([entry])], ignore_index = True)

dfAll_json = dfAll.to_json(orient='records')

with open('institutions.txt', 'w') as f:
    f.write(dfAll_json)
    f.close()

# %% [markdown]
# This code creates a text file containing a json of all the institutions with agreements to De Anza College, as well as one only containing the UCs.

# %%
api_url = "https://assist.org/api/institutions/113/agreements"
response = requests.get(api_url).json()

dfAgree = pd.DataFrame(columns=['id', 'name', 'code', 'isCCC'])

for i in response:
    entry = {'id': i['institutionParentId'], 'name': i['institutionName'], 'code': i['code'], 'isCCC': i['isCommunityCollege'], 'years': i['receivingYearIds']}
    dfAgree = pd.concat([dfAgree, pd.DataFrame([entry])], ignore_index = True)

dfAgree_json = dfAgree.to_json(orient='records')

with open('all_agreements.txt', 'w') as f:
    f.write(dfAgree_json)
    f.close()

uc_json = dfAgree[dfAgree.name.str.contains("University of California")].to_json(orient='records')

with open('uc_agreements.txt', 'w') as f:
    f.write(uc_json)
    f.close()

# %% [markdown]
# This code creates a text file containing all keys for the agreements between the UC's and De Anza College.

# %%
dfUC = dfAgree[dfAgree.name.str.contains("University of California")]
dfKeys = pd.DataFrame(columns=['school', 'label', 'key'])

for i, d in dfUC.iterrows():
    home = "113"
    destination_id = d['id']
    destination_name = d['name']
    years = d['years']
    year = max(years)
    
    api_url = f"https://assist.org/api/agreements?receivingInstitutionId={destination_id}&sendingInstitutionId={home}&academicYearId={year}&categoryCode=major"
    response = requests.get(api_url).json()
    
    for i in response['reports']:
        entry = {'school': destination_name, 'label': i['label'], 'key': i['key']}
        dfKeys = pd.concat([dfKeys, pd.DataFrame([entry])], ignore_index = True)
# Out:
# {'reports': [{'label': 'Anthropology B.A. with Concentration in Biological Anthropology', 'key': 26379265, 'ownerInstitutionId': 0}, {'label': 'Accounting Minor: Rady School of Management', 'key': 26379296, 'ownerInstitutionId': 0}, {'label': 'Business Minor: Rady School of Management', 'key': 26379324, 'ownerInstitutionId': 0}, {'label': 'Anthropology B.A. with Concentration in Archaeology', 'key': 26379352, 'ownerInstitutionId': 0}, {'label': 'Bioengineering B.S.', 'key': 26379385, 'ownerInstitutionId': 0}, {'label': 'Bioengineering: Bioinformatics B.S.', 'key': 26379417, 'ownerInstitutionId': 0}, {'label': 'Bioengineering: BioSystems B.S.', 'key': 26379443, 'ownerInstitutionId': 0}, {'label': 'Bioengineering: Biotechnology B.S.', 'key': 26379475, 'ownerInstitutionId': 0}, {'label': 'Biology with a Specialization in Bioinformatics B.S.', 'key': 26379506, 'ownerInstitutionId': 0}, {'label': 'Biology: Ecology, Behavior, and Evolution B.S.', 'key': 26379537, 'ownerInstitutionId': 0}, {'label': 'Biology: Human Biology B.S.', 'key': 26379563, 'ownerInstitutionId': 0}, {'label': 'Biology: General Biology B.S.', 'key': 26379593, 'ownerInstitutionId': 0}, {'label': 'Biology: Microbiology B.S.', 'key': 26379624, 'ownerInstitutionId': 0}, {'label': 'Chemistry and Biochemistry: Chemistry B.S.', 'key': 26379652, 'ownerInstitutionId': 0}, {'label': 'Chemistry and Biochemistry: Molecular Synthesis B.S.', 'key': 26379686, 'ownerInstitutionId': 0}, {'label': 'Chemistry and Biochemistry: Environmental Chemistry B.S.', 'key': 26379716, 'ownerInstitutionId': 0}, {'label': 'Chemistry and Biochemistry: Pharmacological Chemistry B.S.', 'key': 26379744, 'ownerInstitutionId': 0}, {'label': 'Chinese Studies B.A.', 'key': 26379769, 'ownerInstitutionId': 0}, {'label': 'Classical Studies B.A.', 'key': 26379805, 'ownerInstitutionId': 0}, {'label': 'Cognitive Science B.A.', 'key': 26379838, 'ownerInstitutionId': 0}, {'label': 'Cognitive Science B.S.', 'key': 26379868, 'ownerInstitutionId': 0}, {'label': 'Cognitive Science B.S. Specialization in Clin Aspcts of Cogn', 'key': 26379928, 'ownerInstitutionId': 0}, {'label': 'Cognitive Science B.S. with Specialization in Neuroscience', 'key': 26379990, 'ownerInstitutionId': 0}, {'label': 'Cognitive Science: Cognitive and Behavioral Neuroscience B.S.', 'key': 26380055, 'ownerInstitutionId': 0}, {'label': 'Communication B.A.', 'key': 26380142, 'ownerInstitutionId': 0}, {'label': 'Critical Gender Studies B.A.', 'key': 26380165, 'ownerInstitutionId': 0}, {'label': 'CSE: Computer Engineering B.S.', 'key': 26380211, 'ownerInstitutionId': 0}, {'label': 'CSE: Computer Science B.S.', 'key': 26380278, 'ownerInstitutionId': 0}, {'label': 'CSE: Computer Science with a Specialization in Bioinformatics B.S.', 'key': 26380343, 'ownerInstitutionId': 0}, {'label': 'Dance B.A.', 'key': 26380394, 'ownerInstitutionId': 0}, {'label': 'ECE: Computer Engineering B.S.', 'key': 26380448, 'ownerInstitutionId': 0}, {'label': 'ECE: Electrical Engineering and Society B.A.', 'key': 26380511, 'ownerInstitutionId': 0}, {'label': 'ECE: Electrical Engineering B.S.', 'key': 26380570, 'ownerInstitutionId': 0}, {'label': 'ECE: Engineering Physics B.S.', 'key': 26380626, 'ownerInstitutionId': 0}, {'label': 'Economics B.A.', 'key': 26380678, 'ownerInstitutionId': 0}, {'label': 'Economics: Joint Major in Mathematics and Economics B.S.', 'key': 26380730, 'ownerInstitutionId': 0}, {'label': 'Economics: Management Science B.S.', 'key': 26380776, 'ownerInstitutionId': 0}, {'label': 'Environmental Systems/Earth Sciences B.S.', 'key': 26380826, 'ownerInstitutionId': 0}, {'label': 'Environmental Systems/Ecology, Behavior, and Evolution B.S.', 'key': 26380882, 'ownerInstitutionId': 0}, {'label': 'Environmental Systems/Environmental Chemistry B.S.', 'key': 26380935, 'ownerInstitutionId': 0}, {'label': 'Environmental Systems/Environmental Policy B.A.', 'key': 26380992, 'ownerInstitutionId': 0}, {'label': 'Ethnic Studies B.A.', 'key': 26381049, 'ownerInstitutio ...
# {'reports': [{'label': 'Mechanical Engineering, B.S.', 'key': 26425682, 'ownerInstitutionId': 0}, {'label': 'Chemical Engineering, B.S.', 'key': 26425793, 'ownerInstitutionId': 0}, {'label': 'Environmental Engineering, B.S.', 'key': 26425905, 'ownerInstitutionId': 0}, {'label': 'Bioengineering, B.S.', 'key': 26426019, 'ownerInstitutionId': 0}, {'label': 'Computer Engineering, B.S.', 'key': 26426132, 'ownerInstitutionId': 0}, {'label': 'Electrical Engineering, B.S.', 'key': 26426245, 'ownerInstitutionId': 0}, {'label': 'Materials Science and Engineering, B.S.', 'key': 26426358, 'ownerInstitutionId': 0}, {'label': 'Computer Science with Business Applications B.S.', 'key': 26426471, 'ownerInstitutionId': 0}, {'label': 'Computer Science, B.S.', 'key': 26426585, 'ownerInstitutionId': 0}, {'label': 'Data Science, B.S.', 'key': 26426698, 'ownerInstitutionId': 0}, {'label': 'Robotics, B.S.', 'key': 26426809, 'ownerInstitutionId': 0}, {'label': 'African American Studies, B.A.', 'key': 26428942, 'ownerInstitutionId': 0}, {'label': 'Anthropology, B.A. or B.S.', 'key': 26429057, 'ownerInstitutionId': 0}, {'label': 'Theatre, Film, and Digital Production B.A.', 'key': 26429172, 'ownerInstitutionId': 0}, {'label': 'Sustainability Studies, B.S.', 'key': 26429287, 'ownerInstitutionId': 0}, {'label': 'Sociology, B.A. or B.S.', 'key': 26429402, 'ownerInstitutionId': 0}, {'label': 'Sociology/Administrative Studies, B.A. or B.S.', 'key': 26429517, 'ownerInstitutionId': 0}, {'label': 'Spanish, B.A.', 'key': 26429631, 'ownerInstitutionId': 0}, {'label': 'Religious Studies, B.A.', 'key': 26429747, 'ownerInstitutionId': 0}, {'label': 'Public Policy, B.A.', 'key': 26429862, 'ownerInstitutionId': 0}, {'label': 'Psychology, B.A. and B.S.', 'key': 26429977, 'ownerInstitutionId': 0}, {'label': 'Political Science/International Affairs, B.A.', 'key': 26430092, 'ownerInstitutionId': 0}, {'label': 'Political Science/Public Service, B.A.', 'key': 26430206, 'ownerInstitutionId': 0}, {'label': 'Political Science, B.A.', 'key': 26430322, 'ownerInstitutionId': 0}, {'label': 'Political Science/Administrative Studies, B.A.', 'key': 26430436, 'ownerInstitutionId': 0}, {'label': 'Philosophy, B.A.', 'key': 26430552, 'ownerInstitutionId': 0}, {'label': 'Native American Studies, B.A.', 'key': 26430667, 'ownerInstitutionId': 0}, {'label': 'Music and Culture, B.A.', 'key': 26430782, 'ownerInstitutionId': 0}, {'label': 'Middle East and Islamic Studies, B.A.', 'key': 26430897, 'ownerInstitutionId': 0}, {'label': 'Media and Cultural Studies, B.A.', 'key': 26431012, 'ownerInstitutionId': 0}, {'label': 'Asian Studies, B.A.', 'key': 26431128, 'ownerInstitutionId': 0}, {'label': 'Chicano Studies, B.A.', 'key': 26431241, 'ownerInstitutionId': 0}, {'label': 'Art History, B.A.', 'key': 26431357, 'ownerInstitutionId': 0}, {'label': 'Asian American Studies, B.A.', 'key': 26431473, 'ownerInstitutionId': 0}, {'label': 'Art, B.A.', 'key': 26431585, 'ownerInstitutionId': 0}, {'label': 'Art History/Administrative Studies, B.A.', 'key': 26431702, 'ownerInstitutionId': 0}, {'label': 'Art History/Religious Studies, B.A.', 'key': 26431816, 'ownerInstitutionId': 0}, {'label': 'Dance, B.A.', 'key': 26431932, 'ownerInstitutionId': 0}, {'label': 'English, B.A.', 'key': 26432046, 'ownerInstitutionId': 0}, {'label': 'Business Administration, B.S.', 'key': 26432161, 'ownerInstitutionId': 0}, {'label': 'Business Economics, B.A.', 'key': 26432276, 'ownerInstitutionId': 0}, {'label': 'Economics, B.A.', 'key': 26432392, 'ownerInstitutionId': 0}, {'label': 'Economics/Administrative Studies, B.A.', 'key': 26432508, 'ownerInstitutionId': 0}, {'label': 'Creative Writing, B.A.', 'key': 26432622, 'ownerInstitutionId': 0}, {'label': 'Ethnic Studies, B.A.', 'key': 26432736, 'ownerInstitutionId': 0}, {'label': 'Gender and Sexuality Studies B.A.', 'key': 26432856, 'ownerInstitutionId': 0}, {'label': 'Global Studies, B.A.', 'key': 26432968, 'ownerInstitutionId': 0}, {'label': 'History, B.A.', 'key': 26433084, 'owner ...
# {'reports': [{'label': 'English, Lower Division B.A.', 'key': 26273938, 'ownerInstitutionId': 0}, {'label': 'Anthropology, Lower Division B.A.', 'key': 26273941, 'ownerInstitutionId': 0}, {'label': 'Economics, Lower Division B.A.', 'key': 26273947, 'ownerInstitutionId': 0}, {'label': 'Mathematics/Applied Mathematics, Lower Division B.A.', 'key': 26273952, 'ownerInstitutionId': 0}, {'label': 'Physics, Lower Division B.A.', 'key': 26273958, 'ownerInstitutionId': 0}, {'label': 'Sociology, Lower Division B.A.', 'key': 26273962, 'ownerInstitutionId': 0}, {'label': 'History, Lower Division B.A.', 'key': 26273968, 'ownerInstitutionId': 0}, {'label': 'Philosophy, Lower Division B.A.', 'key': 26273971, 'ownerInstitutionId': 0}, {'label': 'Political Science, Lower Division B.A.', 'key': 26273977, 'ownerInstitutionId': 0}, {'label': 'Psychology, Lower Division B.A.', 'key': 26273982, 'ownerInstitutionId': 0}, {'label': 'Bioengineering, Lower Division B.S.', 'key': 26273986, 'ownerInstitutionId': 0}, {'label': 'Civil Engineering, Lower Division B.S.', 'key': 26273992, 'ownerInstitutionId': 0}, {'label': 'Electrical Engineering & Computer Sciences, Lower Division B.S.', 'key': 26273998, 'ownerInstitutionId': 0}, {'label': 'Energy Engineering, Lower Division B.S.', 'key': 26274001, 'ownerInstitutionId': 0}, {'label': 'Engineering Mathematics and Statistics, Lower Division B.S.', 'key': 26274007, 'ownerInstitutionId': 0}, {'label': 'Engineering Physics, Lower Division B.S.', 'key': 26274012, 'ownerInstitutionId': 0}, {'label': 'Environmental Engineering Science, Lower Division B.S.', 'key': 26274017, 'ownerInstitutionId': 0}, {'label': 'Industrial Engineering & Operations Research, Lower Division B.S.', 'key': 26274022, 'ownerInstitutionId': 0}, {'label': 'Materials Science and Engineering, Lower Division B.S.', 'key': 26274027, 'ownerInstitutionId': 0}, {'label': 'Mechanical Engineering, Lower Division B.S.', 'key': 26274033, 'ownerInstitutionId': 0}, {'label': 'Nuclear Engineering, Lower Division B.S.', 'key': 26274036, 'ownerInstitutionId': 0}, {'label': 'Conservation and Resource Studies, Lower Division B.S.', 'key': 26274042, 'ownerInstitutionId': 0}, {'label': 'Environmental Sciences, Lower Division B.S.', 'key': 26274047, 'ownerInstitutionId': 0}, {'label': 'Genetics and Plant Biology, Lower Division B.S.', 'key': 26274052, 'ownerInstitutionId': 0}, {'label': 'Microbial Biology, Lower Division B.S.', 'key': 26274057, 'ownerInstitutionId': 0}, {'label': 'Molecular Environmental Biology, Lower Division B.S.', 'key': 26274062, 'ownerInstitutionId': 0}, {'label': 'Nutritional Science, Lower Division B.S.', 'key': 26274067, 'ownerInstitutionId': 0}, {'label': 'Society and Environment, Lower Division B.S', 'key': 26274072, 'ownerInstitutionId': 0}, {'label': 'Chemistry, Lower Division B.A. and B.S.', 'key': 26274077, 'ownerInstitutionId': 0}, {'label': 'Chemical Biology, Lower Division B.S.', 'key': 26274082, 'ownerInstitutionId': 0}, {'label': 'Chemical Engineering, Lower Division B.S.', 'key': 26274087, 'ownerInstitutionId': 0}, {'label': 'Architecture, Lower Division B.A.', 'key': 26274093, 'ownerInstitutionId': 0}, {'label': 'Landscape Architecture, Lower Division B.A.', 'key': 26274098, 'ownerInstitutionId': 0}, {'label': 'Sustainable Environmental Design, Lower Division B.A.', 'key': 26274103, 'ownerInstitutionId': 0}, {'label': 'Urban Studies, Lower Division B.A.', 'key': 26274107, 'ownerInstitutionId': 0}, {'label': 'Business Administration, Lower Division B.S.', 'key': 26274111, 'ownerInstitutionId': 0}, {'label': 'African American Studies, Lower Division B.A.', 'key': 26274116, 'ownerInstitutionId': 0}, {'label': 'American Studies, Lower Division B.A.', 'key': 26274123, 'ownerInstitutionId': 0}, {'label': 'Art (Practice of), Lower Division B.A.', 'key': 26274126, 'ownerInstitutionId': 0}, {'label': 'History of Art, Lower Division B.A.', 'key': 26274131, 'ownerInstitutionId': 0}, {'label': 'Asian American and Asian Diaspora Studies ...
# {'reports': [{'label': 'Aerospace Science & Engineering B.S', 'key': 26298808, 'ownerInstitutionId': 0}, {'label': 'Biochemical Engineering B.S.', 'key': 26298817, 'ownerInstitutionId': 0}, {'label': 'Biological Systems Engineering B.S.', 'key': 26298825, 'ownerInstitutionId': 0}, {'label': 'Biomedical Engineering B.S.', 'key': 26298832, 'ownerInstitutionId': 0}, {'label': 'Chemical Engineering B.S.', 'key': 26298841, 'ownerInstitutionId': 0}, {'label': 'Computer Engineering B.S.', 'key': 26298859, 'ownerInstitutionId': 0}, {'label': 'Computer Science & Engineering B.S.', 'key': 26298868, 'ownerInstitutionId': 0}, {'label': 'Electrical Engineering B.S.', 'key': 26298877, 'ownerInstitutionId': 0}, {'label': 'Environmental Engineering B.S.', 'key': 26298885, 'ownerInstitutionId': 0}, {'label': 'Materials Science & Engineering B.S.', 'key': 26298893, 'ownerInstitutionId': 0}, {'label': 'Mechanical Engineering B.S.', 'key': 26298901, 'ownerInstitutionId': 0}, {'label': 'African American & African Studies A.B.', 'key': 26299579, 'ownerInstitutionId': 0}, {'label': 'American Studies A.B.', 'key': 26299607, 'ownerInstitutionId': 0}, {'label': 'Anthropology A.B.', 'key': 26300744, 'ownerInstitutionId': 0}, {'label': 'Asian American Studies A.B.', 'key': 26300751, 'ownerInstitutionId': 0}, {'label': 'Chicana/Chicano Studies A.B', 'key': 26300757, 'ownerInstitutionId': 0}, {'label': 'Chinese A.B.', 'key': 26300765, 'ownerInstitutionId': 0}, {'label': 'Cinema & Digital Media A.B.', 'key': 26300772, 'ownerInstitutionId': 0}, {'label': 'Classical Civilization A.B.', 'key': 26303461, 'ownerInstitutionId': 0}, {'label': 'Cognitive Science A.B.', 'key': 26303471, 'ownerInstitutionId': 0}, {'label': 'Communication A.B.', 'key': 26303481, 'ownerInstitutionId': 0}, {'label': 'Community & Regional Development B.S.', 'key': 26303491, 'ownerInstitutionId': 0}, {'label': 'Comparative Literature A.B.', 'key': 26304427, 'ownerInstitutionId': 0}, {'label': 'Design A.B.', 'key': 26304455, 'ownerInstitutionId': 0}, {'label': 'East Asian Studies A.B.', 'key': 26304486, 'ownerInstitutionId': 0}, {'label': 'English A.B.', 'key': 26306568, 'ownerInstitutionId': 0}, {'label': 'Gender, Sexuality, & Women`s Studies A.B.', 'key': 26306576, 'ownerInstitutionId': 0}, {'label': 'Human Development B.S.', 'key': 26306584, 'ownerInstitutionId': 0}, {'label': 'Japanese A.B.', 'key': 26306591, 'ownerInstitutionId': 0}, {'label': 'Landscape Architecture B.S.', 'key': 26306600, 'ownerInstitutionId': 0}, {'label': 'Linguistics A.B.', 'key': 26306609, 'ownerInstitutionId': 0}, {'label': 'Middle East/South Asia Studies A.B.', 'key': 26306615, 'ownerInstitutionId': 0}, {'label': 'Philosophy A.B.', 'key': 26309213, 'ownerInstitutionId': 0}, {'label': 'Political Science - Public Service A.B.', 'key': 26309609, 'ownerInstitutionId': 0}, {'label': 'Political Science A.B.', 'key': 26310221, 'ownerInstitutionId': 0}, {'label': 'Religious Studies A.B.', 'key': 26310231, 'ownerInstitutionId': 0}, {'label': 'Science & Technology Studies A.B.', 'key': 26310241, 'ownerInstitutionId': 0}, {'label': 'Sociology - Organizational Studies A.B.', 'key': 26310604, 'ownerInstitutionId': 0}, {'label': 'Theatre & Dance A.B.', 'key': 26310632, 'ownerInstitutionId': 0}, {'label': 'Applied Mathematics B.S.', 'key': 26312090, 'ownerInstitutionId': 0}, {'label': 'Applied Physics B.S.', 'key': 26312120, 'ownerInstitutionId': 0}, {'label': 'Biotechnology B.S.', 'key': 26312149, 'ownerInstitutionId': 0}, {'label': 'Economics A.B.', 'key': 26312237, 'ownerInstitutionId': 0}, {'label': 'Managerial Economics B.S.', 'key': 26317751, 'ownerInstitutionId': 0}, {'label': 'Mathematics A.B.', 'key': 26320601, 'ownerInstitutionId': 0}, {'label': 'Mathematical & Scientific Computation B.S.', 'key': 26336669, 'ownerInstitutionId': 0}, {'label': 'Mathematics B.S.', 'key': 26336745, 'ownerInstitutionId': 0}, {'label': 'Mathematical Analytics & Operations Research, B.S.', 'key': 26364264, 'ownerInstitutionId': 0}, {'lab ...
# {'reports': [{'label': 'Aerospace  Engineering/B.S', 'key': 26088781, 'ownerInstitutionId': 0}, {'label': 'Bioengineering/B.S.', 'key': 26088890, 'ownerInstitutionId': 0}, {'label': 'Chemical Engineering/ B.S', 'key': 26088999, 'ownerInstitutionId': 0}, {'label': 'Civil Engineering/B.S.', 'key': 26089108, 'ownerInstitutionId': 0}, {'label': 'Computer Science and Engineering/B.S.', 'key': 26089218, 'ownerInstitutionId': 0}, {'label': 'Computer Science/B.S.', 'key': 26089326, 'ownerInstitutionId': 0}, {'label': 'Electrical Engineering/B.S.', 'key': 26089435, 'ownerInstitutionId': 0}, {'label': 'Materials Engineering/B.S.', 'key': 26089543, 'ownerInstitutionId': 0}, {'label': 'Mechanical Engineering/B.S.', 'key': 26089653, 'ownerInstitutionId': 0}, {'label': 'Biochemistry/B.S.', 'key': 26089761, 'ownerInstitutionId': 0}, {'label': 'Nursing-Generic/Prelicensure/B.S.', 'key': 26089878, 'ownerInstitutionId': 0}, {'label': 'Engineering Geology/B.S.', 'key': 26089994, 'ownerInstitutionId': 0}, {'label': 'Linguistics and Computer Science/B.A.', 'key': 26090107, 'ownerInstitutionId': 0}, {'label': 'Computer Engineering/B.S.', 'key': 26090217, 'ownerInstitutionId': 0}, {'label': 'Atmospheric and Oceanic Sciences/B.S.', 'key': 26090327, 'ownerInstitutionId': 0}, {'label': 'Atmospheric, And Oceanic Sciences/Mathematics/B.S.', 'key': 26090440, 'ownerInstitutionId': 0}, {'label': 'Theater B.A.', 'key': 26148441, 'ownerInstitutionId': 0}, {'label': 'World Arts and Cultures/B.A.', 'key': 26148518, 'ownerInstitutionId': 0}, {'label': 'Biology/B.S.', 'key': 26148627, 'ownerInstitutionId': 0}, {'label': 'Ecology, Behavior, and Evolution/B.S.', 'key': 26148704, 'ownerInstitutionId': 0}, {'label': 'Marine Biology/B.S.', 'key': 26148779, 'ownerInstitutionId': 0}, {'label': 'Neuroscience/B.S.', 'key': 26148855, 'ownerInstitutionId': 0}, {'label': 'Microbiology, Immunology, and Molecular Genetics/B.S.', 'key': 26148930, 'ownerInstitutionId': 0}, {'label': 'Molecular, Cell, and Developmental Biology/B.S.', 'key': 26149007, 'ownerInstitutionId': 0}, {'label': 'Physiological Science/B.S.', 'key': 26149083, 'ownerInstitutionId': 0}, {'label': 'Psychobiology/B.S.', 'key': 26149160, 'ownerInstitutionId': 0}, {'label': 'Human Biology and Society/B.S.', 'key': 26149232, 'ownerInstitutionId': 0}, {'label': 'Psychology/B.A.', 'key': 26149309, 'ownerInstitutionId': 0}, {'label': 'Political Science/B.A.', 'key': 26149385, 'ownerInstitutionId': 0}, {'label': 'Sociology/B.A.', 'key': 26149462, 'ownerInstitutionId': 0}, {'label': 'English/B.A.', 'key': 26149540, 'ownerInstitutionId': 0}, {'label': 'International Development Studies/B.A.', 'key': 26149615, 'ownerInstitutionId': 0}, {'label': 'Chemistry/B.S.', 'key': 26149690, 'ownerInstitutionId': 0}, {'label': 'Human Biology and Society/B.A.', 'key': 26149767, 'ownerInstitutionId': 0}, {'label': 'Mathematics/B.S.', 'key': 26149845, 'ownerInstitutionId': 0}, {'label': 'Mathematics of Computation/B.S.', 'key': 26149914, 'ownerInstitutionId': 0}, {'label': 'Financial Actuarial Mathematics/B.S.', 'key': 26149990, 'ownerInstitutionId': 0}, {'label': 'Mathematics/Economics/B.S.', 'key': 26150070, 'ownerInstitutionId': 0}, {'label': 'History/B.A.', 'key': 26150143, 'ownerInstitutionId': 0}, {'label': 'Anthropology/B.A.', 'key': 26150219, 'ownerInstitutionId': 0}, {'label': 'American Literature and Culture/B.A.', 'key': 26150297, 'ownerInstitutionId': 0}, {'label': 'Geography/B.A.', 'key': 26150372, 'ownerInstitutionId': 0}, {'label': 'Statistics/B.S.', 'key': 26150446, 'ownerInstitutionId': 0}, {'label': 'Anthropology/B.S.', 'key': 26150523, 'ownerInstitutionId': 0}, {'label': 'Art History/B.A.', 'key': 26150600, 'ownerInstitutionId': 0}, {'label': 'Astrophysics/B.S.', 'key': 26150677, 'ownerInstitutionId': 0}, {'label': 'Biophysics/B.S.', 'key': 26150750, 'ownerInstitutionId': 0}, {'label': 'Physics/B.A.', 'key': 26150826, 'ownerInstitutionId': 0}, {'label': 'Physics/B.S.', 'key': 26150896, 'ownerInstitutionId': 0}, {'lab ...
# {'reports': [{'label': 'Mathematics, B.S.', 'key': 26294600, 'ownerInstitutionId': 0}, {'label': 'Anthropology, B.A.', 'key': 26294699, 'ownerInstitutionId': 0}, {'label': 'Biomedical Engineering, B.S.', 'key': 26294701, 'ownerInstitutionId': 0}, {'label': 'Aerospace Engineering, B.S.', 'key': 26294703, 'ownerInstitutionId': 0}, {'label': 'Chemical Engineering, B.S.', 'key': 26294704, 'ownerInstitutionId': 0}, {'label': 'Civil Engineering, B.S.', 'key': 26294707, 'ownerInstitutionId': 0}, {'label': 'Mechanical Engineering, B.S.', 'key': 26294709, 'ownerInstitutionId': 0}, {'label': 'Biomedical Engineering: Pre-Medical, B.S.', 'key': 26294710, 'ownerInstitutionId': 0}, {'label': 'Computer Science and Engineering, B.S.', 'key': 26294713, 'ownerInstitutionId': 0}, {'label': 'Computer Engineering, B.S.', 'key': 26294715, 'ownerInstitutionId': 0}, {'label': 'Electrical Engineering, B.S.', 'key': 26294716, 'ownerInstitutionId': 0}, {'label': 'Environmental Engineering, B.S.', 'key': 26294718, 'ownerInstitutionId': 0}, {'label': 'Computer Science, B.S.', 'key': 26294721, 'ownerInstitutionId': 0}, {'label': 'Data Science, B.S.', 'key': 26294724, 'ownerInstitutionId': 0}, {'label': 'Informatics, B.S.', 'key': 26294725, 'ownerInstitutionId': 0}, {'label': 'Software Engineering, B.S.', 'key': 26294727, 'ownerInstitutionId': 0}, {'label': 'Accounting (Minor in)', 'key': 26294730, 'ownerInstitutionId': 0}, {'label': 'Nursing Science, B.S.', 'key': 26294731, 'ownerInstitutionId': 0}, {'label': 'Innovation and Entrepreneurship (Minor in)', 'key': 26294734, 'ownerInstitutionId': 0}, {'label': 'Business Administration, B.A.', 'key': 26294735, 'ownerInstitutionId': 0}, {'label': 'Business Information Management, B.S.', 'key': 26294739, 'ownerInstitutionId': 0}, {'label': 'African American Studies, B.A.', 'key': 26294741, 'ownerInstitutionId': 0}, {'label': 'Applied Physics, B.S.', 'key': 26294742, 'ownerInstitutionId': 0}, {'label': 'Biochemistry and Molecular Biology, B.S.', 'key': 26294743, 'ownerInstitutionId': 0}, {'label': 'Biological Sciences, B.S.', 'key': 26294746, 'ownerInstitutionId': 0}, {'label': 'Biology/Education, B.S.', 'key': 26294749, 'ownerInstitutionId': 0}, {'label': 'Business Economics, B.A.', 'key': 26294750, 'ownerInstitutionId': 0}, {'label': 'Chemistry, B.S.', 'key': 26294751, 'ownerInstitutionId': 0}, {'label': 'Art History, B.A.', 'key': 26294753, 'ownerInstitutionId': 0}, {'label': 'Art, B.A.', 'key': 26294754, 'ownerInstitutionId': 0}, {'label': 'Asian American Studies, B.A.', 'key': 26294756, 'ownerInstitutionId': 0}, {'label': 'Developmental and Cell Biology, B.S.', 'key': 26294760, 'ownerInstitutionId': 0}, {'label': 'Chicano/Latino Studies, B.A.', 'key': 26294761, 'ownerInstitutionId': 0}, {'label': 'Genetics, B.S.', 'key': 26294762, 'ownerInstitutionId': 0}, {'label': 'Ecology and Evolutionary Biology, B.S.', 'key': 26294763, 'ownerInstitutionId': 0}, {'label': 'Microbiology and Immunology, B.S.', 'key': 26294767, 'ownerInstitutionId': 0}, {'label': 'Neurobiology, B.S.', 'key': 26294768, 'ownerInstitutionId': 0}, {'label': 'Earth System Science, B.S.', 'key': 26294771, 'ownerInstitutionId': 0}, {'label': 'Physics, B.S.', 'key': 26294774, 'ownerInstitutionId': 0}, {'label': 'Dance, B.A., B.F.A.', 'key': 26294775, 'ownerInstitutionId': 0}, {'label': 'Drama, B.A.', 'key': 26294778, 'ownerInstitutionId': 0}, {'label': 'Music, B.A./B.Mus.', 'key': 26294780, 'ownerInstitutionId': 0}, {'label': 'Music Theatre, B.F.A.', 'key': 26294782, 'ownerInstitutionId': 0}, {'label': 'Education Sciences, B.A.', 'key': 26294783, 'ownerInstitutionId': 0}, {'label': 'Education (Minor in)', 'key': 26294785, 'ownerInstitutionId': 0}, {'label': 'Pharmaceutical Sciences, B.S.', 'key': 26294787, 'ownerInstitutionId': 0}, {'label': 'Criminology, Law and Society, B.A.', 'key': 26294790, 'ownerInstitutionId': 0}, {'label': 'Social Ecology, B.A.', 'key': 26294792, 'ownerInstitutionId': 0}, {'label': 'Urban Studies, B.A.', 'key': 26294793, 'ow ...
# {'reports': [{'label': 'Actuarial Science, B.S.', 'key': 26428764, 'ownerInstitutionId': 0}, {'label': 'Anthropology, B.A.', 'key': 26428765, 'ownerInstitutionId': 0}, {'label': 'Anthropology, B.A. - Biological Emphasis', 'key': 26428766, 'ownerInstitutionId': 0}, {'label': 'Anthropology, B.A. - Archaeology Emphasis', 'key': 26428768, 'ownerInstitutionId': 0}, {'label': 'Anthropology, B.A. - Cultural Emphasis', 'key': 26428769, 'ownerInstitutionId': 0}, {'label': 'Art, B.A.', 'key': 26428770, 'ownerInstitutionId': 0}, {'label': 'Aquatic Biology, B.S.', 'key': 26428771, 'ownerInstitutionId': 0}, {'label': 'Asian American Studies, B.A.', 'key': 26428772, 'ownerInstitutionId': 0}, {'label': 'Biochemistry, B.S.', 'key': 26428773, 'ownerInstitutionId': 0}, {'label': 'Biochemistry-Molecular Biology, B.S.', 'key': 26428774, 'ownerInstitutionId': 0}, {'label': 'Asian Studies, B.A.', 'key': 26428775, 'ownerInstitutionId': 0}, {'label': 'Biological Sciences, B.A. & B.S.', 'key': 26428776, 'ownerInstitutionId': 0}, {'label': 'Biopsychology, B.S.', 'key': 26428777, 'ownerInstitutionId': 0}, {'label': 'Black Studies, B.A.', 'key': 26428778, 'ownerInstitutionId': 0}, {'label': 'Cell and Developmental Biology, B.S.', 'key': 26428779, 'ownerInstitutionId': 0}, {'label': 'Chemical Engineering, B.S.', 'key': 26428780, 'ownerInstitutionId': 0}, {'label': 'Chemistry, B.A.', 'key': 26428781, 'ownerInstitutionId': 0}, {'label': 'Chemistry, B.S.', 'key': 26428782, 'ownerInstitutionId': 0}, {'label': 'Chicana and Chicano Studies, B.A.', 'key': 26428783, 'ownerInstitutionId': 0}, {'label': 'Classics, B.A. - Classical Archaeology Emphasis', 'key': 26428784, 'ownerInstitutionId': 0}, {'label': 'Chinese, B.A.', 'key': 26428785, 'ownerInstitutionId': 0}, {'label': 'Classics, B.A. - Classical Language and Literature Emphasis', 'key': 26428786, 'ownerInstitutionId': 0}, {'label': 'Classics, B.A. - Greek and Roman Culture Emphasis', 'key': 26428787, 'ownerInstitutionId': 0}, {'label': 'Communication, B.A.', 'key': 26428788, 'ownerInstitutionId': 0}, {'label': 'Comparative Literature, B.A.', 'key': 26428789, 'ownerInstitutionId': 0}, {'label': 'Creative Studies - Art, B.A.', 'key': 26428790, 'ownerInstitutionId': 0}, {'label': 'Computer Engineering, B.S.', 'key': 26428791, 'ownerInstitutionId': 0}, {'label': 'Creative Studies - Biology, B.A.', 'key': 26428792, 'ownerInstitutionId': 0}, {'label': 'Creative Studies - Chemistry and Biochemistry, B.A. & B.S.', 'key': 26428793, 'ownerInstitutionId': 0}, {'label': 'Creative Studies - Computing, B.S.', 'key': 26428794, 'ownerInstitutionId': 0}, {'label': 'Creative Studies - Mathematics, B.A. & B.S.', 'key': 26428795, 'ownerInstitutionId': 0}, {'label': 'Creative Studies - Music Composition, B.A.', 'key': 26428796, 'ownerInstitutionId': 0}, {'label': 'Creative Studies - Physics, B.A. & B.S.', 'key': 26428797, 'ownerInstitutionId': 0}, {'label': 'Computer Science, B.S.', 'key': 26428798, 'ownerInstitutionId': 0}, {'label': 'Creative Studies - Writing and Literature, B.A.', 'key': 26428799, 'ownerInstitutionId': 0}, {'label': 'Dance, B.A.', 'key': 26428800, 'ownerInstitutionId': 0}, {'label': 'Dance, B.F.A.', 'key': 26428801, 'ownerInstitutionId': 0}, {'label': 'Earth Science, B.A.', 'key': 26428802, 'ownerInstitutionId': 0}, {'label': 'Earth Science, B.S. - Climate and Environment Emphasis', 'key': 26428803, 'ownerInstitutionId': 0}, {'label': 'Earth Science, B.S. - Geohydrology Emphasis', 'key': 26428804, 'ownerInstitutionId': 0}, {'label': 'Earth Science, B.S. - Geology Emphasis', 'key': 26428805, 'ownerInstitutionId': 0}, {'label': 'Earth Science, B.S. - Geophysics Emphasis', 'key': 26428806, 'ownerInstitutionId': 0}, {'label': 'Earth Science, B.S. - Paleobiology Emphasis', 'key': 26428807, 'ownerInstitutionId': 0}, {'label': 'Economics and Accounting, B.A.', 'key': 26428808, 'ownerInstitutionId': 0}, {'label': 'Ecology and Evolution, B.S.', 'key': 26428809, 'ownerInstitutionId': 0}, {'label': 'Economics, B.A.', 'k ...
# {'reports': [{'label': 'Anthropology B.A.', 'key': 26353335, 'ownerInstitutionId': 0}, {'label': 'Applied Physics B.S.', 'key': 26353339, 'ownerInstitutionId': 0}, {'label': 'Biology B.S.', 'key': 26353342, 'ownerInstitutionId': 0}, {'label': 'Art and Design: Games and Playable Media B.A.', 'key': 26353344, 'ownerInstitutionId': 0}, {'label': 'Biology B.A.', 'key': 26353345, 'ownerInstitutionId': 0}, {'label': 'Business Management Economics B.A.', 'key': 26353346, 'ownerInstitutionId': 0}, {'label': 'Community Studies B.A.', 'key': 26353347, 'ownerInstitutionId': 0}, {'label': 'Chemistry B.A.', 'key': 26353348, 'ownerInstitutionId': 0}, {'label': 'Biochemistry and Molecular Biology B.S.', 'key': 26353349, 'ownerInstitutionId': 0}, {'label': 'Art B.A.', 'key': 26353350, 'ownerInstitutionId': 0}, {'label': 'Cognitive Science B.S.', 'key': 26353351, 'ownerInstitutionId': 0}, {'label': 'Chemistry B.S.', 'key': 26353352, 'ownerInstitutionId': 0}, {'label': 'Critical Race and Ethnic Studies B.A.', 'key': 26353353, 'ownerInstitutionId': 0}, {'label': 'Computer Science B.S.', 'key': 26353354, 'ownerInstitutionId': 0}, {'label': 'Computer Science B.A.', 'key': 26353355, 'ownerInstitutionId': 0}, {'label': 'Latin American & Latino Studies/Politics Combined B.A.', 'key': 26353356, 'ownerInstitutionId': 0}, {'label': 'Classical Studies B.A.', 'key': 26353357, 'ownerInstitutionId': 0}, {'label': 'Computer Engineering B.S.', 'key': 26353358, 'ownerInstitutionId': 0}, {'label': 'Feminist Studies B.A.', 'key': 26353359, 'ownerInstitutionId': 0}, {'label': 'History of Art And Visual Culture B.A.', 'key': 26353360, 'ownerInstitutionId': 0}, {'label': 'Legal Studies B.A.', 'key': 26353361, 'ownerInstitutionId': 0}, {'label': 'Computer Science: Computer Game Design B.S.', 'key': 26353362, 'ownerInstitutionId': 0}, {'label': 'Jewish Studies B.A.', 'key': 26353363, 'ownerInstitutionId': 0}, {'label': 'Science, Technology, Engineering & Mathematics (STEM) Education Minor', 'key': 26353364, 'ownerInstitutionId': 0}, {'label': 'Philosophy B.A.', 'key': 26353365, 'ownerInstitutionId': 0}, {'label': 'Film and Digital Media B.A.', 'key': 26353366, 'ownerInstitutionId': 0}, {'label': 'Music B.A.', 'key': 26353367, 'ownerInstitutionId': 0}, {'label': 'Language Studies B.A.', 'key': 26353368, 'ownerInstitutionId': 0}, {'label': 'Literature B.A.', 'key': 26353369, 'ownerInstitutionId': 0}, {'label': 'Linguistics B.A.', 'key': 26353370, 'ownerInstitutionId': 0}, {'label': 'Politics B.A.', 'key': 26353371, 'ownerInstitutionId': 0}, {'label': 'History B.A.', 'key': 26353372, 'ownerInstitutionId': 0}, {'label': 'Music B.M.', 'key': 26353373, 'ownerInstitutionId': 0}, {'label': 'Latin American & Latino Studies B.A.', 'key': 26353374, 'ownerInstitutionId': 0}, {'label': 'Earth Sciences, Ocean Sciences Concentration B.S.', 'key': 26353375, 'ownerInstitutionId': 0}, {'label': 'Spanish Studies B.A.', 'key': 26353376, 'ownerInstitutionId': 0}, {'label': 'Earth Sciences/Anthropology Combined B.A.', 'key': 26353377, 'ownerInstitutionId': 0}, {'label': 'Sociology B.A.', 'key': 26353378, 'ownerInstitutionId': 0}, {'label': 'Earth Sciences B.S.', 'key': 26353379, 'ownerInstitutionId': 0}, {'label': 'Psychology B.A.', 'key': 26353380, 'ownerInstitutionId': 0}, {'label': 'Theater Arts B.A.', 'key': 26353381, 'ownerInstitutionId': 0}, {'label': 'Sociology, Global Information and Social Enterprise Studies Concentration B.A.', 'key': 26353382, 'ownerInstitutionId': 0}, {'label': 'Economics B.A.', 'key': 26353383, 'ownerInstitutionId': 0}, {'label': 'Economics/Mathematics Combined B.A.', 'key': 26353384, 'ownerInstitutionId': 0}, {'label': 'Global Economics B.A.', 'key': 26353385, 'ownerInstitutionId': 0}, {'label': 'Ecology and Evolution B.S.', 'key': 26353386, 'ownerInstitutionId': 0}, {'label': 'Environmental Studies B.A.', 'key': 26353387, 'ownerInstitutionId': 0}, {'label': 'Network and Digital Technology B.A.', 'key': 26353388, 'ownerInstitutionId': 0}, {'label': 'Neurosci ...
# {'reports': [{'label': 'Anthropology, B.A. ', 'key': 26517895, 'ownerInstitutionId': 0}, {'label': 'Applied Mathematical Sciences, Computational and Data Sciences Emphasis, B.S.', 'key': 26517899, 'ownerInstitutionId': 0}, {'label': 'Applied Mathematical Sciences, Computational Biology Emphasis, B.S.', 'key': 26517902, 'ownerInstitutionId': 0}, {'label': 'Applied Mathematical Sciences, Computer Science Emphasis, B.S.', 'key': 26517909, 'ownerInstitutionId': 0}, {'label': 'Applied Mathematical Sciences, Economics Emphasis, B.S.', 'key': 26517910, 'ownerInstitutionId': 0}, {'label': 'Applied Mathematical Sciences, Engineering Emphasis, B.S.', 'key': 26517911, 'ownerInstitutionId': 0}, {'label': 'Applied Mathematical Sciences, Environmental Emphasis, B.S. ', 'key': 26517912, 'ownerInstitutionId': 0}, {'label': 'Bioengineering, Biomedical Imaging and Bioinstrumentation Emphasis, B.S. ', 'key': 26517913, 'ownerInstitutionId': 0}, {'label': 'Applied Mathematical Sciences, Physics Emphasis, B.S.', 'key': 26517914, 'ownerInstitutionId': 0}, {'label': 'Bioengineering, Biotechnology Emphasis, B.S.', 'key': 26517915, 'ownerInstitutionId': 0}, {'label': 'Biological Sciences, Developmental Biology Emphasis, B.S.', 'key': 26517916, 'ownerInstitutionId': 0}, {'label': 'Biological Sciences, Ecology and Evolutionary Biology Emphasis, B.S.', 'key': 26517917, 'ownerInstitutionId': 0}, {'label': 'Biological Sciences, Human Biology Emphasis, B.S.', 'key': 26517918, 'ownerInstitutionId': 0}, {'label': 'Biological Sciences, Microbiology and Immunology Emphasis, B.S.', 'key': 26517919, 'ownerInstitutionId': 0}, {'label': 'Biological Sciences, Molecular and Cell Biology Emphasis, B.S.', 'key': 26517920, 'ownerInstitutionId': 0}, {'label': 'Chemistry, Chemistry Emphasis, B.S.', 'key': 26517921, 'ownerInstitutionId': 0}, {'label': 'Chemistry, Biological Chemistry Emphasis, B.S.', 'key': 26517922, 'ownerInstitutionId': 0}, {'label': 'Civil Engineering, B.S.', 'key': 26517923, 'ownerInstitutionId': 0}, {'label': 'Chemistry, Materials Chemistry Emphasis, B.S.', 'key': 26517924, 'ownerInstitutionId': 0}, {'label': 'Cognitive Science, B.A.', 'key': 26517925, 'ownerInstitutionId': 0}, {'label': 'Critical Race and Ethnic Studies, B.A. ', 'key': 26517926, 'ownerInstitutionId': 0}, {'label': 'Cognitive Science, B.S.', 'key': 26517927, 'ownerInstitutionId': 0}, {'label': 'Economics, B.A.', 'key': 26517928, 'ownerInstitutionId': 0}, {'label': 'Computer Science and Engineering, B.S. ', 'key': 26517929, 'ownerInstitutionId': 0}, {'label': 'Economics, Economic Analysis and Policy Emphasis, B.S.', 'key': 26517930, 'ownerInstitutionId': 0}, {'label': 'Economics, Quantitative Economics Emphasis, B.S.', 'key': 26517931, 'ownerInstitutionId': 0}, {'label': 'Electrical Engineering, B.S. (Available Fall 2025)', 'key': 26517932, 'ownerInstitutionId': 0}, {'label': 'Environmental Engineering, B.S. ', 'key': 26517933, 'ownerInstitutionId': 0}, {'label': 'English, B.A.', 'key': 26517934, 'ownerInstitutionId': 0}, {'label': 'Environmental Systems Science, B.S.', 'key': 26517935, 'ownerInstitutionId': 0}, {'label': 'Global Arts Studies, B.A.', 'key': 26517936, 'ownerInstitutionId': 0}, {'label': 'Global Art Studies, Performance Studies Emphasis, B.A. ', 'key': 26517937, 'ownerInstitutionId': 0}, {'label': 'Global Arts Studies, Visual Studies Emphasis, B. A.', 'key': 26517938, 'ownerInstitutionId': 0}, {'label': 'History, B.A. ', 'key': 26517939, 'ownerInstitutionId': 0}, {'label': 'Management and Business Economics, B.S.', 'key': 26517940, 'ownerInstitutionId': 0}, {'label': 'Materials Science and Engineering, B.S. ', 'key': 26517941, 'ownerInstitutionId': 0}, {'label': 'Materials Science and Engineering, Nanotechnology emphasis, B.S.', 'key': 26517942, 'ownerInstitutionId': 0}, {'label': 'Philosophy, B.A. ', 'key': 26517943, 'ownerInstitutionId': 0}, {'label': 'Mechanical Engineering, B.S. ', 'key': 26517944, 'ownerInstitutionId': 0}, {'label': 'Physics, Astrophysics Emphasis, B ...
